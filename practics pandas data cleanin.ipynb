# %% [markdown]
# https://www.youtube.com/watch?v=iaZQF8SLHJs&t=51s

# %%
import pandas as pd

# %%
df=pd.read_excel("espn cricket.xlsx")
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4   H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df.head(5)
# Out:
#               Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0   DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1     AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2    RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3    GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4  H Sutcliffe (ENG)  1924-1935   54    84   9  4555   194  60.73  6558+
#
#       SR  100  50  0    4s  6s
# 0  58.60   29  13  7  626+   6
# 1  55.68    5   4  2   186   5
# 2  54.48    7  11  1  246+  11
# 3  56.00   10   5  2  104+   1
# 4  34.59   16  23  2  202+   6

# %%
df.shape
# Out:
# (65, 15)

# %%
df.columns
# Out:
# Index(['Player',   'Span',    'Mat',   'Inns',     'NO',   'Runs',     'HS',
#           'Ave',     'BF',     'SR',      100,       50,        0,     '4s',
#            '6s'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=65, step=1)

# %%
#rename multiple columns for a better understanding

df=df.rename(columns={"NO":"NOT_OUT",
                      "HS":"HIGHEST_SCORE",
                     "BF":"BALL_FACED",
                     "SR":"STRIKE_RATES",
                     "MAT":"MATCHES"})
df
# Out:
#                Player       Span  Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE  \
# 0    DG Bradman (AUS)  1928-1948   52    80       10  6996           334
# 1      AC Voges (AUS)  2015-2016   20    31        7  1485          269*
# 2     RG Pollock (SA)  1963-1970   23    41        4  2256           274
# 3     GA Headley (WI)  1930-1954   22    40        4  2190          270*
# 4   H Sutcliffe (ENG)  1924-1935   54    84        9  4555           194
# ..                ...        ...  ...   ...      ...   ...           ...
# 60   KD Walters (AUS)  1965-1981   74   125       14  5357           250
# 61  GC Smith (ICC/SA)  2002-2014  117   205       13  9265           277
# 62  WH Ponsford (AUS)  1924-1934   29    48        4  2122           266
# 63    SJ McCabe (AUS)  1930-1938   39    62        5  2748           232
# 64   DR Jardine (ENG)  1928-1934   22    33        6  1296           127
#
#       Ave BALL_FACED  STRIKE_RATES  100  50   0    4s  6s
# ...

# %%
#check null value

df.isnull().any()
# Out:
# Player           False
# Span             False
# Mat              False
# Inns             False
# NOT_OUT          False
# Runs             False
# HIGHEST_SCORE    False
# Ave              False
# BALL_FACED       False
# STRIKE_RATES      True
# 100              False
# 50               False
# 0                False
# 4s               False
# 6s               False
# dtype: bool

# %%
#as above code shows that STRIKE_RATES has a null value, to see that null value row
df[df["STRIKE_RATES"].isna()==True]
# Out:
#            Player       Span  Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE    Ave  \
# 7  ED Weekes (WI)  1948-1958   48    81        5  4455           207  58.61
#
#   BALL_FACED  STRIKE_RATES  100  50  0    4s 6s
# 7       4957           NaN   15  19  6  258+  2

# %%
#to fix it
df["STRIKE_RATES"]=df["STRIKE_RATES"].fillna(0)
df.isnull().sum() #so now no more null value is the dataframe
# Out:
# Player           0
# Span             0
# Mat              0
# Inns             0
# NOT_OUT          0
# Runs             0
# HIGHEST_SCORE    0
# Ave              0
# BALL_FACED       0
# STRIKE_RATES     0
# 100              0
# 50               0
# 0                0
# 4s               0
# 6s               0
# dtype: int64

# %%
df[df["Player"]=="ED Weekes (WI)"] #now see 0 filled inside the null value
# Out:
#            Player       Span  Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE    Ave  \
# 7  ED Weekes (WI)  1948-1958   48    81        5  4455           207  58.61
#
#   BALL_FACED  STRIKE_RATES  100  50  0    4s 6s
# 7       4957           0.0   15  19  6  258+  2

# %%
df=df.drop_duplicates()
df
# Out:
#                Player       Span  Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE  \
# 0    DG Bradman (AUS)  1928-1948   52    80       10  6996           334
# 1      AC Voges (AUS)  2015-2016   20    31        7  1485          269*
# 2     RG Pollock (SA)  1963-1970   23    41        4  2256           274
# 3     GA Headley (WI)  1930-1954   22    40        4  2190          270*
# 4   H Sutcliffe (ENG)  1924-1935   54    84        9  4555           194
# ..                ...        ...  ...   ...      ...   ...           ...
# 60   KD Walters (AUS)  1965-1981   74   125       14  5357           250
# 61  GC Smith (ICC/SA)  2002-2014  117   205       13  9265           277
# 62  WH Ponsford (AUS)  1924-1934   29    48        4  2122           266
# 63    SJ McCabe (AUS)  1930-1938   39    62        5  2748           232
# 64   DR Jardine (ENG)  1928-1934   22    33        6  1296           127
#
#       Ave BALL_FACED  STRIKE_RATES  100  50   0    4s  6s
# ...

# %%
#split up span into start and end date

df[["starting_year","last_year"]]=df["Span"].str.split("-",expand=True)
df
# Out:
# C:\Users\atrey\AppData\Local\Temp\ipykernel_15392\1097675551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["starting_year","last_year"]]=df["Span"].str.split("-",expand=True)
# C:\Users\atrey\AppData\Local\Temp\ipykernel_15392\1097675551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["starting_year","last_year"]]=df["Span"].str.split("-",expand=True)
#                Player       Span  Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE  \
# ...

# %%
df=df.drop(columns="Span")

# %%
#removing country code from the player column

df["Player"].str.split("(",expand=True)
# Out:
#                0        1
# 0    DG Bradman      AUS)
# 1      AC Voges      AUS)
# 2    RG Pollock       SA)
# 3    GA Headley       WI)
# 4   H Sutcliffe      ENG)
# ..           ...      ...
# 60   KD Walters      AUS)
# 61     GC Smith   ICC/SA)
# 62  WH Ponsford      AUS)
# 63    SJ McCabe      AUS)
# 64   DR Jardine      ENG)
#
# [62 rows x 2 columns]

# %%
df["Player"].str.split("(").str[0]
#spliting the player col, and assigning the 1st index value as player_name
# Out:
# 0      DG Bradman
# 1        AC Voges
# 2      RG Pollock
# 3      GA Headley
# 4     H Sutcliffe
#           ...
# 60     KD Walters
# 61       GC Smith
# 62    WH Ponsford
# 63      SJ McCabe
# 64     DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
df["Player_name"]=df["Player"].str.split("(").str[0]
df
# Out:
#                Player  Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE    Ave  \
# 0    DG Bradman (AUS)   52    80       10  6996           334  99.94
# 1      AC Voges (AUS)   20    31        7  1485          269*  61.87
# 2     RG Pollock (SA)   23    41        4  2256           274  60.97
# 3     GA Headley (WI)   22    40        4  2190          270*  60.83
# 4   H Sutcliffe (ENG)   54    84        9  4555           194  60.73
# ..                ...  ...   ...      ...   ...           ...    ...
# 60   KD Walters (AUS)   74   125       14  5357           250  48.26
# 61  GC Smith (ICC/SA)  117   205       13  9265           277  48.25
# 62  WH Ponsford (AUS)   29    48        4  2122           266  48.22
# 63    SJ McCabe (AUS)   39    62        5  2748           232  48.21
# 64   DR Jardine (ENG)   22    33        6  1296           127  48.00
#
#    BALL_FACED  STRIKE_RATES  100  50   0    4s  6s starting_year last_year  \
# ...

# %%
df["country"]=df["Player"].str.split("(").str[1]
df
# Out:
#                Player  Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE    Ave  \
# 0    DG Bradman (AUS)   52    80       10  6996           334  99.94
# 1      AC Voges (AUS)   20    31        7  1485          269*  61.87
# 2     RG Pollock (SA)   23    41        4  2256           274  60.97
# 3     GA Headley (WI)   22    40        4  2190          270*  60.83
# 4   H Sutcliffe (ENG)   54    84        9  4555           194  60.73
# ..                ...  ...   ...      ...   ...           ...    ...
# 60   KD Walters (AUS)   74   125       14  5357           250  48.26
# 61  GC Smith (ICC/SA)  117   205       13  9265           277  48.25
# 62  WH Ponsford (AUS)   29    48        4  2122           266  48.22
# 63    SJ McCabe (AUS)   39    62        5  2748           232  48.21
# 64   DR Jardine (ENG)   22    33        6  1296           127  48.00
#
#    BALL_FACED  STRIKE_RATES  100  50   0    4s  6s starting_year last_year  \
# ...

# %%
df=df.drop(columns="Player",axis=0)
df
# Out:
#     Mat  Inns  NOT_OUT  Runs HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10  6996           334  99.94      9800+         58.60
# 1    20    31        7  1485          269*  61.87       2667         55.68
# 2    23    41        4  2256           274  60.97      1707+         54.48
# 3    22    40        4  2190          270*  60.83       416+         56.00
# 4    54    84        9  4555           194  60.73      6558+         34.59
# ..  ...   ...      ...   ...           ...    ...        ...           ...
# 60   74   125       14  5357           250  48.26      8662+         49.16
# 61  117   205       13  9265           277  48.25      15525         59.67
# 62   29    48        4  2122           266  48.22      3118+         44.77
# 63   39    62        5  2748           232  48.21      3217+         60.02
# 64   22    33        6  1296           127  48.00      2110+         25.59
#
# ...

# %%
df.dtypes
# Out:
# Mat                int64
# Inns               int64
# NOT_OUT            int64
# Runs               int64
# HIGHEST_SCORE     object
# Ave              float64
# BALL_FACED        object
# STRIKE_RATES     float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# starting_year     object
# last_year         object
# Player_name       object
# country           object
# dtype: object

# %%
#now see the highest score is a object dtypes and we want to remove the *,and convert it into int

df['HIGHEST_SCORE']=df['HIGHEST_SCORE'].apply(lambda x: x.replace('*', '') if isinstance(x, str) else x)
#The lambda function checks if the element is a string (isinstance(x, str)). If it is, it replaces "*"
#with an empty string (x.replace('*', '')). If it's not a string (e.g., NaN), it leaves the element unchanged (else x).                          
df
# Out:
#     Mat  Inns  NOT_OUT   Runs  HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10   6996            334  99.94      9800+         58.60
# 1    20    31        7   1485            269  61.87       2667         55.68
# 2    23    41        4   2256            274  60.97      1707+         54.48
# 3    22    40        4   2190            270  60.83       416+         56.00
# 4    54    84        9   4555            194  60.73      6558+         34.59
# 5    20    31        5   1540            243  59.23      1288+         45.88
# 6    82   131       15   6806            256  58.67       4957         42.42
# 7    48    81        5   4455            207  58.61       4957          0.00
# 8    85   140       16   7249            336  58.45      7491+         38.07
# 9    93   160       21   8032            365  57.78      4063+         53.58
# 10  134   233       17  12400            319  57.40      22882         54.19
# ...

# %% [markdown]
# #if any columns consist of this kind of issue, then we can do like above code
#
# for i in df["HIGHEST_SCORE"]:
#     if  isinstance(i,str) and "*" in i:
#         print(i)
#
# Check if the Entry is a String: The isinstance(i, str) check ensures that only string values are checked for the presence of "*". This prevents the error you encountered.

# %%
df["HIGHEST_SCORE"]=df["HIGHEST_SCORE"].astype("int")
df.dtypes
# Out:
# Mat                int64
# Inns               int64
# NOT_OUT            int64
# Runs               int64
# HIGHEST_SCORE      int32
# Ave              float64
# BALL_FACED        object
# STRIKE_RATES     float64
# 100                int64
# 50                 int64
# 0                  int64
# 4s                object
# 6s                object
# starting_year     object
# last_year         object
# Player_name       object
# country           object
# dtype: object

# %%
#converting data types of columns in a one go 

df=df.astype({"starting_year":"int",
             "last_year":"int",
             })
df
# Out:
#     Mat  Inns  NOT_OUT  Runs  HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10  6996            334  99.94      9800+         58.60
# 1    20    31        7  1485            269  61.87       2667         55.68
# 2    23    41        4  2256            274  60.97      1707+         54.48
# 3    22    40        4  2190            270  60.83       416+         56.00
# 4    54    84        9  4555            194  60.73      6558+         34.59
# ..  ...   ...      ...   ...            ...    ...        ...           ...
# 60   74   125       14  5357            250  48.26      8662+         49.16
# 61  117   205       13  9265            277  48.25      15525         59.67
# 62   29    48        4  2122            266  48.22      3118+         44.77
# 63   39    62        5  2748            232  48.21      3217+         60.02
# 64   22    33        6  1296            127  48.00      2110+         25.59
#
# ...

# %%
pd.set_option("display.max_rows",None)
df
# Out:
#     Mat  Inns  NOT_OUT   Runs  HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10   6996            334  99.94      9800+         58.60
# 1    20    31        7   1485            269  61.87       2667         55.68
# 2    23    41        4   2256            274  60.97      1707+         54.48
# 3    22    40        4   2190            270  60.83       416+         56.00
# 4    54    84        9   4555            194  60.73      6558+         34.59
# 5    20    31        5   1540            243  59.23      1288+         45.88
# 6    82   131       15   6806            256  58.67       4957         42.42
# 7    48    81        5   4455            207  58.61       4957          0.00
# 8    85   140       16   7249            336  58.45      7491+         38.07
# 9    93   160       21   8032            365  57.78      4063+         53.58
# 10  134   233       17  12400            319  57.40      22882         54.19
# ...

# %%
#now we removing + from the BALL_FACED

df.dropna() #droping nan values
df.replace("-","") # to replace "-", by ""
df.isnull().any() #to check if any null present 

df['BALL_FACED'] = df['BALL_FACED'].apply(lambda x: x.strip("+") if isinstance(x, str) else x)
#isinstance(x, str): Check if x is a string,x.strip("+"): Remove the "+" character from the string.

#df["BALL_FACED"].astype("int")
df
# Out:
#     Mat  Inns  NOT_OUT   Runs  HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10   6996            334  99.94       9800         58.60
# 1    20    31        7   1485            269  61.87       2667         55.68
# 2    23    41        4   2256            274  60.97       1707         54.48
# 3    22    40        4   2190            270  60.83        416         56.00
# 4    54    84        9   4555            194  60.73       6558         34.59
# 5    20    31        5   1540            243  59.23       1288         45.88
# 6    82   131       15   6806            256  58.67       4957         42.42
# 7    48    81        5   4455            207  58.61       4957          0.00
# 8    85   140       16   7249            336  58.45       7491         38.07
# 9    93   160       21   8032            365  57.78       4063         53.58
# 10  134   233       17  12400            319  57.40      22882         54.19
# ...

# %%
#REMOVING + FROM THE 4S col
df["4s"]=df["4s"].apply(lambda x: x.strip("+") if isinstance(x,str) else x)

# %%
#removing ) from the country 
df["country"]=df["country"].apply(lambda x: x.strip(")") if isinstance(x,str) else x)

# %%
df
# Out:
#     Mat  Inns  NOT_OUT   Runs  HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10   6996            334  99.94       9800         58.60
# 1    20    31        7   1485            269  61.87       2667         55.68
# 2    23    41        4   2256            274  60.97       1707         54.48
# 3    22    40        4   2190            270  60.83        416         56.00
# 4    54    84        9   4555            194  60.73       6558         34.59
# 5    20    31        5   1540            243  59.23       1288         45.88
# 6    82   131       15   6806            256  58.67       4957         42.42
# 7    48    81        5   4455            207  58.61       4957          0.00
# 8    85   140       16   7249            336  58.45       7491         38.07
# 9    93   160       21   8032            365  57.78       4063         53.58
# 10  134   233       17  12400            319  57.40      22882         54.19
# ...

# %%
#carrer lenght of any player

df["carrer_lenght"]=df["last_year"]-df["starting_year"]
df
# Out:
#     Mat  Inns  NOT_OUT   Runs  HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10   6996            334  99.94       9800         58.60
# 1    20    31        7   1485            269  61.87       2667         55.68
# 2    23    41        4   2256            274  60.97       1707         54.48
# 3    22    40        4   2190            270  60.83        416         56.00
# 4    54    84        9   4555            194  60.73       6558         34.59
# 5    20    31        5   1540            243  59.23       1288         45.88
# 6    82   131       15   6806            256  58.67       4957         42.42
# 7    48    81        5   4455            207  58.61       4957          0.00
# 8    85   140       16   7249            336  58.45       7491         38.07
# 9    93   160       21   8032            365  57.78       4063         53.58
# 10  134   233       17  12400            319  57.40      22882         54.19
# ...

# %%
#avg career length of all players

df["carrer_lenght"].mean()
# Out:
# 12.96774193548387

# %%
#avg batting strike rate ,thoes who play more than 10 years
df[df["carrer_lenght"]>10]["STRIKE_RATES"].mean()
# Out:
# 47.785348837209305

# %%
#find number of player played before 1950
df[df["last_year"]<1950]
# Out:
#     Mat  Inns  NOT_OUT  Runs  HIGHEST_SCORE    Ave BALL_FACED  STRIKE_RATES  \
# 0    52    80       10  6996            334  99.94       9800         58.60
# 4    54    84        9  4555            194  60.73       6558         34.59
# 5    20    31        5  1540            243  59.23       1288         45.88
# 8    85   140       16  7249            336  58.45       7491         38.07
# 13   61   102        7  5410            211  56.94       5363         46.22
# 20   14    20        2   990            122  55.00        178         29.21
# 34   20    32        5  1394            201  51.62       2035         44.86
# 42   17    26        2  1185            182  49.37        619         30.04
# 56   42    80        9  3471            189  48.88        158         29.11
# 57   20    33        4  1415            144  48.79          -          0.00
# 62   29    48        4  2122            266  48.22       3118         44.77
# ...

# %%
#4 max highest score by country
df.groupby("country")["HIGHEST_SCORE"].max()
df.sort_values(ascending=False)
# Out:
# country
# ICC/WI     400
# AUS        380
# SL         374
# WI         365
# ENG        364
# ICC/PAK    329
# ICC/IND    319
# PAK        313
# SA         278
# ICC/SA     277
# NZ         251
# IND        248
# ZIM        232
# Name: HIGHEST_SCORE, dtype: int64

# %%
df.columns
# Out:
# Index([          'Mat',          'Inns',       'NOT_OUT',          'Runs',
#        'HIGHEST_SCORE',           'Ave',    'BALL_FACED',  'STRIKE_RATES',
#                    100,              50,               0,            '4s',
#                   '6s', 'starting_year',     'last_year',   'Player_name',
#              'country', 'carrer_lenght'],
#       dtype='object')

# %%
# hundred,fifties,ducks (0) avg by country

df.groupby('country')[[100,50,0.]].mean()
# Out:
#                100         50          0
# country
# AUS      20.625000  28.375000   8.562500
# ENG      12.846154  21.230769   4.307692
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      23.000000  31.000000   7.500000
# NZ       32.000000  35.000000  11.000000
# PAK      17.800000  23.800000   7.800000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
